# %%
import pandas as pd
data = pd.read_html('data/dtp.html', encoding='utf-8')

# %%
data = data[0].iloc[4:len(data[0])]

# %%
data.head(3)
# Out:
#                       0       1    2     3      4    5       6     7
# 4  Российская Федерация  199720  -21  1000  26963  -02  251785 -26.0
# 5  Белгородская область    1302   06    07    270   55    1462 -31.0
# 6      Брянская область    1448  -26    07    278   65    1742  -6.0

# %%
data.columns = ['region', 'dtp_abs', 'dtp_increase', 'dtp_weight', 'death_abs', 'death_increase', 'injured_abs', 'injured_increase']

# %%
data
# Out:
#                                 region dtp_abs dtp_increase dtp_weight  \
# 4                 Российская Федерация  199720          -21       1000
# 5                 Белгородская область    1302           06         07
# 6                     Брянская область    1448          -26         07
# 7                 Владимирская область    3089           32         15
# 8                  Воронежская область    3555           -7         18
# 9                   Ивановская область    1948           04         10
# 10                   Калужская область    2417           39         12
# 11                 Костромская область     927          149         05
# 12                     Курская область    2037          -04         10
# 13                    Липецкая область    1977          -72         10
# 14                           г. Москва   11312          -01         57
# 15                  Московская область    9044          -27         45
# ...
